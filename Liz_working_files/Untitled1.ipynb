# %%
#dependencies%matplotlib notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
from scipy.stats import linregress
import seaborn as sns


#data file to work with
file = '../cleanData/CleanFullDataSet.csv'

#read data file
clean_data = pd.read_csv(file, low_memory = False)

# %%
clean_data
# Out:
#        yearOfRegistration       Datasource  gender ageBroad majorityStatus  \
# 0                    2002  Case Management  Female   18--20          Adult
# 1                    2002  Case Management  Female   18--20          Adult
# 2                    2002  Case Management  Female   18--20          Adult
# 3                    2002  Case Management  Female   18--20          Adult
# 4                    2002  Case Management  Female   18--20          Adult
# ...                   ...              ...     ...      ...            ...
# 48768                2018          Hotline    Male    9--17          Minor
# 48769                2018          Hotline    Male    9--17          Minor
# 48770                2018          Hotline    Male    9--17          Minor
# 48771                2018          Hotline    Male    9--17          Minor
# 48772                2018          Hotline    Male    9--17          Minor
#
#       majorityStatusAtExploit majorityEntry citizenship  \
# ...
